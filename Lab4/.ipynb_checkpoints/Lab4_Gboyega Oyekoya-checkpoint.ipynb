# %%
# Install spaCy and download the English model if not already installed
# !pip install spacy
# !python -m spacy download en_core_web_sm

import spacy

# Load the spaCy English model
nlp = spacy.load("en_core_web_sm")

# Example text
# Text1 — Industrial Safety Incident Example (Hydraulic Leak) Source: SEE Forge Creators of FAT FINGER Aug 23, 2023
text1 = """The personnel directly involved were Alex and Maya. Initial inspection indicates a potential hydraulic fluid leakage. 
Documentation of Incident: An incident report was prepared with details of the event, initial observations, and photographs of the
affected area. Root Cause Analysis: Preliminary findings suggest that inadequate maintenance led to the hydraulic system’s malfunction"""
#text2 — Mining Safety NLP Analysis Context Source:MDPI
text2 = """To achieve the goal of preventing serious injuries and fatalities, it is important for a mine site to analyze site specific 
mine safety data. The advances in natural language processing create an opportunity to develop machine learning tools to automate analysis 
of mine health and safety management systems data without requiring experts at every mine site. If causation and associated details can be
automatically extracted from the safety reports, NLP can be used to quickly gain insight into safety incidents from historical reports that
are filed away in the safety management databases."""
#text3 - Text sample — Adverse Drug Event Definition & NLP Potential Source: Wikipedia
text3 = """Pharmacovigilance, also known as drug safety, is the discipline within pharmaceutical science that addresses the identification, 
evaluation, and mitigation of adverse effects and other drug-related problems associated with pharmaceutical products. A central concern is
adverse drug reactions, defined as harmful and unintended responses to a medicinal product."""
#text4 - Text sample — Medication Error Reports Context Source:Nature
text4 = """Incident reports of medication errors are valuable learning resources for improving patient safety. Pertinent information is often
contained within unstructured free text, which prevents automated analysis and limits the usefulness of these data. NLP can structure this free
text automatically and retrieve relevant past incidents and learning materials"""
#text5 - Text sample — Incident Report Process Source: OHSE
text5 = """Key components of an incident investigation report include: Incident Overview — a brief summary including date, time, location, and
nature of the incident; Background Information — a description of site conditions, equipment, and personnel involved; Summary of Findings — linking
identified root causes and contributing factors; and Recommendations — specific corrective and preventive actions."""
# Process the text
doc1 = nlp(text1)
doc2 = nlp(text2)
doc3 = nlp(text3)
doc4 = nlp(text4)
doc5 = nlp(text5)

print("\n")
# Out:
# Requirement already satisfied: spacy in c:\users\gokoy\anaconda3\lib\site-packages (3.8.11)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\gokoy\anaconda3\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\gokoy\anaconda3\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\gokoy\anaconda3\lib\site-packages (from spacy) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\gokoy\anaconda3\lib\site-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\gokoy\anaconda3\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in c:\users\gokoy\anaconda3\lib\site-packages (from spacy) (8.3.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\gokoy\anaconda3\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\gokoy\anaconda3\lib\site-packages (from spacy) (2.5.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\gokoy\anaconda3\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.4.2 in c:\users\gokoy\anaconda3\lib\site-packages (from spacy) (0.4.3)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in c:\users\gokoy\anaconda3\lib\site-packages (from spacy) (0.21.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\gokoy\anaconda3\lib\site-packages (from spacy) (4.65.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\gokoy\anaconda3\lib\site-packages (from spacy) (1.24.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\gokoy\appdata\roaming\python\python311\site-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\gokoy\anaconda3\lib\site-packages (from spacy) (2.12.5)
# Requirement already satisfied: jinja2 in c:\users\gokoy\appdata\roaming\python\python311\site-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\gokoy\anaconda3\lib\site-packages (from spacy) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\gokoy\appdata\roaming\python\python311\site-packages (from spacy) (24.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\gokoy\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\gokoy\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\users\gokoy\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\gokoy\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.4.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gokoy\appdata\roaming\python\python311\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gokoy\appdata\roaming\python\python311\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gokoy\appdata\roaming\python\python311\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gokoy\appdata\roaming\python\python311\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.8.30)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in c:\users\gokoy\anaconda3\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.3)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\gokoy\anaconda3\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: colorama in c:\users\gokoy\appdata\roaming\python\python311\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\gokoy\anaconda3\lib\site-packages (from typer-slim<1.0.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\gokoy\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.4.2->spacy) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\gokoy\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.4.2->spacy) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\gokoy\appdata\roaming\python\python311\site-packages (from jinja2->spacy) (3.0.2)
# [notice] A new release of pip is available: 24.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      -- ------------------------------------- 0.8/12.8 MB 4.8 MB/s eta 0:00:03
#      --------- ------------------------------ 3.1/12.8 MB 8.8 MB/s eta 0:00:02
#      ------------------ --------------------- 6.0/12.8 MB 10.9 MB/s eta 0:00:01
#      --------------------------- ------------ 8.9/12.8 MB 11.5 MB/s eta 0:00:01
#      ----------------------------------- --- 11.8/12.8 MB 11.9 MB/s eta 0:00:01
#      --------------------------------------- 12.8/12.8 MB 11.3 MB/s eta 0:00:00
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# [notice] A new release of pip is available: 24.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# 1. Tokenization with Part-of-speech and Dependency Parsing
print("=== Tokenization, POS, and Dependency Parsing ===\n")

docs = {
    "Industrial Safety": doc1,
    "Mining Safety": doc2,
    "Pharmacovigilance": doc3,
    "Medication Errors": doc4,
    "Incident Reporting": doc5
}

for category, doc in docs.items():
    print(f"\n--- {category} ---\n")
    
    for token in doc:
        print(f"{token.text:20} POS: {token.pos_:10} Dep: {token.dep_}")
# Out:
# === Tokenization, POS, and Dependency Parsing ===
#
#
# --- Industrial Safety ---
#
# The                  POS: DET        Dep: det
# personnel            POS: NOUN       Dep: nsubj
# directly             POS: ADV        Dep: advmod
# involved             POS: ADJ        Dep: acl
# were                 POS: AUX        Dep: ROOT
# Alex                 POS: PROPN      Dep: attr
# and                  POS: CCONJ      Dep: cc
# Maya                 POS: PROPN      Dep: conj
# .                    POS: PUNCT      Dep: punct
# Initial              POS: ADJ        Dep: amod
# inspection           POS: NOUN       Dep: nsubj
# indicates            POS: VERB       Dep: ROOT
# a                    POS: DET        Dep: det
# potential            POS: ADJ        Dep: amod
# hydraulic            POS: ADJ        Dep: amod
# fluid                POS: NOUN       Dep: compound
# leakage              POS: NOUN       Dep: dobj
# .                    POS: PUNCT      Dep: punct
#
#                     POS: SPACE      Dep: dep
# Documentation        POS: PROPN      Dep: ROOT
# of                   POS: ADP        Dep: prep
# Incident             POS: PROPN      Dep: pobj
# :                    POS: PUNCT      Dep: punct
# An                   POS: DET        Dep: det
# incident             POS: NOUN       Dep: compound
# report               POS: NOUN       Dep: nsubjpass
# was                  POS: AUX        Dep: auxpass
# prepared             POS: VERB       Dep: ROOT
# with                 POS: ADP        Dep: prep
# details              POS: NOUN       Dep: pobj
# of                   POS: ADP        Dep: prep
# the                  POS: DET        Dep: det
# event                POS: NOUN       Dep: pobj
# ,                    POS: PUNCT      Dep: punct
# initial              POS: ADJ        Dep: amod
# observations         POS: NOUN       Dep: conj
# ,                    POS: PUNCT      Dep: punct
# and                  POS: CCONJ      Dep: cc
# photographs          POS: NOUN       Dep: conj
# of                   POS: ADP        Dep: prep
# the                  POS: DET        Dep: det
#
#                     POS: SPACE      Dep: dep
# affected             POS: ADJ        Dep: amod
# area                 POS: NOUN       Dep: pobj
# .                    POS: PUNCT      Dep: punct
# Root                 POS: PROPN      Dep: compound
# Cause                POS: PROPN      Dep: compound
# Analysis             POS: NOUN       Dep: dep
# :                    POS: PUNCT      Dep: punct
# Preliminary          POS: ADJ        Dep: amod
# findings             POS: NOUN       Dep: nsubj
# suggest              POS: VERB       Dep: ROOT
# that                 POS: SCONJ      Dep: prep
# inadequate           POS: ADJ        Dep: amod
# maintenance          POS: NOUN       Dep: dobj
# led                  POS: VERB       Dep: acl
# to                   POS: ADP        Dep: prep
# the                  POS: DET        Dep: det
# hydraulic            POS: ADJ        Dep: amod
# system               POS: NOUN       Dep: poss
# ’s                   POS: PART       Dep: case
# malfunction          POS: NOUN       Dep: pobj
#
# --- Mining Safety ---
#
# To                   POS: PART       Dep: aux
# achieve              POS: VERB       Dep: advcl
# the                  POS: DET        Dep: det
# goal                 POS: NOUN       Dep: dobj
# of                   POS: ADP        Dep: prep
# preventing           POS: VERB       Dep: pcomp
# serious              POS: ADJ        Dep: amod
# injuries             POS: NOUN       Dep: dobj
# and                  POS: CCONJ      Dep: cc
# fatalities           POS: NOUN       Dep: conj
# ,                    POS: PUNCT      Dep: punct
# it                   POS: PRON       Dep: nsubj
# is                   POS: AUX        Dep: ROOT
# important            POS: ADJ        Dep: acomp
# for                  POS: SCONJ      Dep: mark
# a                    POS: DET        Dep: det
# mine                 POS: NOUN       Dep: compound
# site                 POS: NOUN       Dep: nsubj
# to                   POS: PART       Dep: aux
# analyze              POS: VERB       Dep: advcl
# site                 POS: NOUN       Dep: nmod
# specific             POS: ADJ        Dep: amod
#
#                     POS: SPACE      Dep: dep
# mine                 POS: ADJ        Dep: compound
# safety               POS: NOUN       Dep: compound
# data                 POS: NOUN       Dep: dobj
# .                    POS: PUNCT      Dep: punct
# The                  POS: DET        Dep: det
# advances             POS: NOUN       Dep: nsubj
# in                   POS: ADP        Dep: prep
# natural              POS: ADJ        Dep: amod
# language             POS: NOUN       Dep: compound
# processing           POS: NOUN       Dep: pobj
# create               POS: VERB       Dep: ROOT
# an                   POS: DET        Dep: det
# opportunity          POS: NOUN       Dep: dobj
# to                   POS: PART       Dep: aux
# develop              POS: VERB       Dep: acl
# machine              POS: NOUN       Dep: compound
# learning             POS: NOUN       Dep: compound
# tools                POS: NOUN       Dep: dobj
# to                   POS: PART       Dep: aux
# automate             POS: VERB       Dep: advcl
# analysis             POS: NOUN       Dep: dobj
#
#                     POS: SPACE      Dep: dep
# of                   POS: ADP        Dep: prep
# mine                 POS: ADJ        Dep: amod
# health               POS: NOUN       Dep: nmod
# and                  POS: CCONJ      Dep: cc
# safety               POS: NOUN       Dep: conj
# management           POS: NOUN       Dep: compound
# systems              POS: NOUN       Dep: compound
# data                 POS: NOUN       Dep: pobj
# without              POS: ADP        Dep: prep
# requiring            POS: VERB       Dep: pcomp
# experts              POS: NOUN       Dep: dobj
# at                   POS: ADP        Dep: prep
# every                POS: DET        Dep: det
# mine                 POS: NOUN       Dep: compound
# site                 POS: NOUN       Dep: pobj
# .                    POS: PUNCT      Dep: punct
# If                   POS: SCONJ      Dep: mark
# causation            POS: NOUN       Dep: nsubjpass
# and                  POS: CCONJ      Dep: cc
# associated           POS: VERB       Dep: amod
# details              POS: NOUN       Dep: conj
# can                  POS: AUX        Dep: aux
# be                   POS: AUX        Dep: auxpass
#
#                     POS: SPACE      Dep: dep
# automatically        POS: ADV        Dep: advmod
# extracted            POS: VERB       Dep: advcl
# from                 POS: ADP        Dep: prep
# the                  POS: DET        Dep: det
# safety               POS: NOUN       Dep: compound
# reports              POS: NOUN       Dep: pobj
# ,                    POS: PUNCT      Dep: punct
# NLP                  POS: PROPN      Dep: nsubjpass
# can                  POS: AUX        Dep: aux
# be                   POS: AUX        Dep: auxpass
# used                 POS: VERB       Dep: ROOT
# to                   POS: PART       Dep: aux
# quickly              POS: ADV        Dep: advmod
# gain                 POS: VERB       Dep: xcomp
# insight              POS: NOUN       Dep: dobj
# into                 POS: ADP        Dep: prep
# safety               POS: NOUN       Dep: compound
# incidents            POS: NOUN       Dep: pobj
# from                 POS: ADP        Dep: prep
# historical           POS: ADJ        Dep: amod
# reports              POS: NOUN       Dep: pobj
# that                 POS: PRON       Dep: nsubjpass
#
#                     POS: SPACE      Dep: dep
# are                  POS: AUX        Dep: auxpass
# filed                POS: VERB       Dep: relcl
# away                 POS: ADV        Dep: advmod
# in                   POS: ADP        Dep: prep
# the                  POS: DET        Dep: det
# safety               POS: NOUN       Dep: compound
# management           POS: NOUN       Dep: compound
# databases            POS: NOUN       Dep: pobj
# .                    POS: PUNCT      Dep: punct
#
# --- Pharmacovigilance ---
#
# Pharmacovigilance    POS: NOUN       Dep: nsubj
# ,                    POS: PUNCT      Dep: punct
# also                 POS: ADV        Dep: advmod
# known                POS: VERB       Dep: acl
# as                   POS: ADP        Dep: prep
# drug                 POS: NOUN       Dep: compound
# safety               POS: NOUN       Dep: pobj
# ,                    POS: PUNCT      Dep: punct
# is                   POS: AUX        Dep: ROOT
# the                  POS: DET        Dep: det
# discipline           POS: NOUN       Dep: attr
# within               POS: ADP        Dep: prep
# pharmaceutical       POS: ADJ        Dep: amod
# science              POS: NOUN       Dep: pobj
# that                 POS: PRON       Dep: nsubj
# addresses            POS: VERB       Dep: relcl
# the                  POS: DET        Dep: det
# identification       POS: NOUN       Dep: dobj
# ,                    POS: PUNCT      Dep: punct
#
#                     POS: SPACE      Dep: dep
# evaluation           POS: NOUN       Dep: conj
# ,                    POS: PUNCT      Dep: punct
# and                  POS: CCONJ      Dep: cc
# mitigation           POS: NOUN       Dep: conj
# of                   POS: ADP        Dep: prep
# adverse              POS: ADJ        Dep: amod
# effects              POS: NOUN       Dep: pobj
# and                  POS: CCONJ      Dep: cc
# other                POS: ADJ        Dep: amod
# drug                 POS: NOUN       Dep: npadvmod
# -                    POS: PUNCT      Dep: punct
# related              POS: VERB       Dep: amod
# problems             POS: NOUN       Dep: conj
# associated           POS: VERB       Dep: acl
# with                 POS: ADP        Dep: prep
# pharmaceutical       POS: ADJ        Dep: amod
# products             POS: NOUN       Dep: pobj
# .                    POS: PUNCT      Dep: punct
# A                    POS: DET        Dep: det
# central              POS: ADJ        Dep: amod
# concern              POS: NOUN       Dep: nsubj
# is                   POS: AUX        Dep: ROOT
#
#                     POS: SPACE      Dep: dep
# adverse              POS: ADJ        Dep: amod
# drug                 POS: NOUN       Dep: compound
# reactions            POS: NOUN       Dep: attr
# ,                    POS: PUNCT      Dep: punct
# defined              POS: VERB       Dep: acl
# as                   POS: ADP        Dep: prep
# harmful              POS: ADJ        Dep: amod
# and                  POS: CCONJ      Dep: cc
# unintended           POS: ADJ        Dep: conj
# responses            POS: NOUN       Dep: pobj
# to                   POS: ADP        Dep: prep
# a                    POS: DET        Dep: det
# medicinal            POS: ADJ        Dep: amod
# product              POS: NOUN       Dep: pobj
# .                    POS: PUNCT      Dep: punct
#
# --- Medication Errors ---
#
# Incident             POS: NOUN       Dep: compound
# reports              POS: NOUN       Dep: nsubj
# of                   POS: ADP        Dep: prep
# medication           POS: NOUN       Dep: compound
# errors               POS: NOUN       Dep: pobj
# are                  POS: AUX        Dep: ROOT
# valuable             POS: ADJ        Dep: amod
# learning             POS: VERB       Dep: compound
# resources            POS: NOUN       Dep: attr
# for                  POS: ADP        Dep: prep
# improving            POS: VERB       Dep: pcomp
# patient              POS: ADJ        Dep: amod
# safety               POS: NOUN       Dep: dobj
# .                    POS: PUNCT      Dep: punct
# Pertinent            POS: ADJ        Dep: amod
# information          POS: NOUN       Dep: nsubjpass
# is                   POS: AUX        Dep: auxpass
# often                POS: ADV        Dep: advmod
#
#                     POS: SPACE      Dep: dep
# contained            POS: VERB       Dep: ROOT
# within               POS: ADP        Dep: prep
# unstructured         POS: ADJ        Dep: amod
# free                 POS: ADJ        Dep: amod
# text                 POS: NOUN       Dep: pobj
# ,                    POS: PUNCT      Dep: punct
# which                POS: PRON       Dep: nsubj
# prevents             POS: VERB       Dep: relcl
# automated            POS: VERB       Dep: amod
# analysis             POS: NOUN       Dep: dobj
# and                  POS: CCONJ      Dep: cc
# limits               POS: VERB       Dep: conj
# the                  POS: DET        Dep: det
# usefulness           POS: NOUN       Dep: dobj
# of                   POS: ADP        Dep: prep
# these                POS: DET        Dep: det
# data                 POS: NOUN       Dep: pobj
# .                    POS: PUNCT      Dep: punct
# NLP                  POS: PROPN      Dep: nsubj
# can                  POS: AUX        Dep: aux
# structure            POS: VERB       Dep: ROOT
# this                 POS: DET        Dep: det
# free                 POS: ADJ        Dep: amod
#
#                     POS: SPACE      Dep: dep
# text                 POS: NOUN       Dep: dobj
# automatically        POS: ADV        Dep: advmod
# and                  POS: CCONJ      Dep: cc
# retrieve             POS: VERB       Dep: conj
# relevant             POS: ADJ        Dep: amod
# past                 POS: ADJ        Dep: amod
# incidents            POS: NOUN       Dep: dobj
# and                  POS: CCONJ      Dep: cc
# learning             POS: VERB       Dep: conj
# materials            POS: NOUN       Dep: dobj
#
# --- Incident Reporting ---
#
# Key                  POS: ADJ        Dep: amod
# components           POS: NOUN       Dep: nsubj
# of                   POS: ADP        Dep: prep
# an                   POS: DET        Dep: det
# incident             POS: NOUN       Dep: compound
# investigation        POS: NOUN       Dep: compound
# report               POS: NOUN       Dep: pobj
# include              POS: VERB       Dep: ROOT
# :                    POS: PUNCT      Dep: punct
# Incident             POS: PROPN      Dep: compound
# Overview             POS: PROPN      Dep: dobj
# —                    POS: PUNCT      Dep: punct
# a                    POS: DET        Dep: det
# brief                POS: ADJ        Dep: amod
# summary              POS: NOUN       Dep: appos
# including            POS: VERB       Dep: prep
# date                 POS: NOUN       Dep: pobj
# ,                    POS: PUNCT      Dep: punct
# time                 POS: NOUN       Dep: conj
# ,                    POS: PUNCT      Dep: punct
# location             POS: NOUN       Dep: conj
# ,                    POS: PUNCT      Dep: punct
# and                  POS: CCONJ      Dep: cc
#
#                     POS: SPACE      Dep: dep
# nature               POS: NOUN       Dep: conj
# of                   POS: ADP        Dep: prep
# the                  POS: DET        Dep: det
# incident             POS: NOUN       Dep: pobj
# ;                    POS: PUNCT      Dep: punct
# Background           POS: PROPN      Dep: compound
# Information          POS: PROPN      Dep: conj
# —                    POS: PUNCT      Dep: punct
# a                    POS: DET        Dep: det
# description          POS: NOUN       Dep: appos
# of                   POS: ADP        Dep: prep
# site                 POS: NOUN       Dep: compound
# conditions           POS: NOUN       Dep: pobj
# ,                    POS: PUNCT      Dep: punct
# equipment            POS: NOUN       Dep: conj
# ,                    POS: PUNCT      Dep: punct
# and                  POS: CCONJ      Dep: cc
# personnel            POS: NOUN       Dep: conj
# involved             POS: VERB       Dep: amod
# ;                    POS: PUNCT      Dep: punct
# Summary              POS: PROPN      Dep: appos
# of                   POS: ADP        Dep: prep
# Findings             POS: PROPN      Dep: pobj
# —                    POS: PUNCT      Dep: punct
# linking              POS: VERB       Dep: acl
#
#                     POS: SPACE      Dep: dep
# identified           POS: VERB       Dep: amod
# root                 POS: NOUN       Dep: compound
# causes               POS: NOUN       Dep: dobj
# and                  POS: CCONJ      Dep: cc
# contributing         POS: VERB       Dep: conj
# factors              POS: NOUN       Dep: dobj
# ;                    POS: PUNCT      Dep: punct
# and                  POS: CCONJ      Dep: cc
# Recommendations      POS: NOUN       Dep: conj
# —                    POS: PUNCT      Dep: punct
# specific             POS: ADJ        Dep: amod
# corrective           POS: ADJ        Dep: amod
# and                  POS: CCONJ      Dep: cc
# preventive           POS: ADJ        Dep: conj
# actions              POS: NOUN       Dep: appos
# .                    POS: PUNCT      Dep: punct

# %%
# 2. Named Entity Recognition (NER)
print("=== Named Entities Recognition ===\n")

docs = {
    "Industrial Safety": doc1,
    "Mining Safety": doc2,
    "Pharmacovigilance": doc3,
    "Medication Errors": doc4,
    "Incident Reporting": doc5
}

for category, doc in docs.items():
    print(f"\n--- {category} ---")
    
    for ent in doc.ents:
        print(f"Entity: {ent.text:25} Label: {ent.label_}")
# Out:
# === Named Entities Recognition ===
#
#
# --- Industrial Safety ---
# Entity: Alex and Maya             Label: WORK_OF_ART
# Entity: Documentation of Incident Label: ORG
# Entity: Root Cause Analysis:      Label: ORG
#
# --- Mining Safety ---
# Entity: NLP                       Label: ORG
#
# --- Pharmacovigilance ---
#
# --- Medication Errors ---
# Entity: NLP                       Label: ORG
#
# --- Incident Reporting ---
# Entity: Background Information    Label: ORG
# Entity: Recommendations           Label: PERSON

# %%
# 3. Lemmatization
print("\n=== Lemmatization ===\n")

for category, doc in docs.items():
    print(f"\n--- {category} ---")
    
    for token in doc:
        print(f"{token.text:20} Lemma: {token.lemma_}")
# Out:
# === Lemmatization ===
#
#
# --- Industrial Safety ---
# The                  Lemma: the
# personnel            Lemma: personnel
# directly             Lemma: directly
# involved             Lemma: involved
# were                 Lemma: be
# Alex                 Lemma: Alex
# and                  Lemma: and
# Maya                 Lemma: Maya
# .                    Lemma: .
# Initial              Lemma: initial
# inspection           Lemma: inspection
# indicates            Lemma: indicate
# a                    Lemma: a
# potential            Lemma: potential
# hydraulic            Lemma: hydraulic
# fluid                Lemma: fluid
# leakage              Lemma: leakage
# .                    Lemma: .
#
#                     Lemma:
#
# Documentation        Lemma: Documentation
# of                   Lemma: of
# Incident             Lemma: Incident
# :                    Lemma: :
# An                   Lemma: an
# incident             Lemma: incident
# report               Lemma: report
# was                  Lemma: be
# prepared             Lemma: prepare
# with                 Lemma: with
# details              Lemma: detail
# of                   Lemma: of
# the                  Lemma: the
# event                Lemma: event
# ,                    Lemma: ,
# initial              Lemma: initial
# observations         Lemma: observation
# ,                    Lemma: ,
# and                  Lemma: and
# photographs          Lemma: photograph
# of                   Lemma: of
# the                  Lemma: the
#
#                     Lemma:
#
# affected             Lemma: affected
# area                 Lemma: area
# .                    Lemma: .
# Root                 Lemma: Root
# Cause                Lemma: Cause
# Analysis             Lemma: analysis
# :                    Lemma: :
# Preliminary          Lemma: preliminary
# findings             Lemma: finding
# suggest              Lemma: suggest
# that                 Lemma: that
# inadequate           Lemma: inadequate
# maintenance          Lemma: maintenance
# led                  Lemma: lead
# to                   Lemma: to
# the                  Lemma: the
# hydraulic            Lemma: hydraulic
# system               Lemma: system
# ’s                   Lemma: ’s
# malfunction          Lemma: malfunction
#
# --- Mining Safety ---
# To                   Lemma: to
# achieve              Lemma: achieve
# the                  Lemma: the
# goal                 Lemma: goal
# of                   Lemma: of
# preventing           Lemma: prevent
# serious              Lemma: serious
# injuries             Lemma: injury
# and                  Lemma: and
# fatalities           Lemma: fatality
# ,                    Lemma: ,
# it                   Lemma: it
# is                   Lemma: be
# important            Lemma: important
# for                  Lemma: for
# a                    Lemma: a
# mine                 Lemma: mine
# site                 Lemma: site
# to                   Lemma: to
# analyze              Lemma: analyze
# site                 Lemma: site
# specific             Lemma: specific
#
#                     Lemma:
#
# mine                 Lemma: mine
# safety               Lemma: safety
# data                 Lemma: datum
# .                    Lemma: .
# The                  Lemma: the
# advances             Lemma: advance
# in                   Lemma: in
# natural              Lemma: natural
# language             Lemma: language
# processing           Lemma: processing
# create               Lemma: create
# an                   Lemma: an
# opportunity          Lemma: opportunity
# to                   Lemma: to
# develop              Lemma: develop
# machine              Lemma: machine
# learning             Lemma: learning
# tools                Lemma: tool
# to                   Lemma: to
# automate             Lemma: automate
# analysis             Lemma: analysis
#
#                     Lemma:
#
# of                   Lemma: of
# mine                 Lemma: mine
# health               Lemma: health
# and                  Lemma: and
# safety               Lemma: safety
# management           Lemma: management
# systems              Lemma: system
# data                 Lemma: datum
# without              Lemma: without
# requiring            Lemma: require
# experts              Lemma: expert
# at                   Lemma: at
# every                Lemma: every
# mine                 Lemma: mine
# site                 Lemma: site
# .                    Lemma: .
# If                   Lemma: if
# causation            Lemma: causation
# and                  Lemma: and
# associated           Lemma: associate
# details              Lemma: detail
# can                  Lemma: can
# be                   Lemma: be
#
#                     Lemma:
#
# automatically        Lemma: automatically
# extracted            Lemma: extract
# from                 Lemma: from
# the                  Lemma: the
# safety               Lemma: safety
# reports              Lemma: report
# ,                    Lemma: ,
# NLP                  Lemma: NLP
# can                  Lemma: can
# be                   Lemma: be
# used                 Lemma: use
# to                   Lemma: to
# quickly              Lemma: quickly
# gain                 Lemma: gain
# insight              Lemma: insight
# into                 Lemma: into
# safety               Lemma: safety
# incidents            Lemma: incident
# from                 Lemma: from
# historical           Lemma: historical
# reports              Lemma: report
# that                 Lemma: that
#
#                     Lemma:
#
# are                  Lemma: be
# filed                Lemma: file
# away                 Lemma: away
# in                   Lemma: in
# the                  Lemma: the
# safety               Lemma: safety
# management           Lemma: management
# databases            Lemma: database
# .                    Lemma: .
#
# --- Pharmacovigilance ---
# Pharmacovigilance    Lemma: pharmacovigilance
# ,                    Lemma: ,
# also                 Lemma: also
# known                Lemma: know
# as                   Lemma: as
# drug                 Lemma: drug
# safety               Lemma: safety
# ,                    Lemma: ,
# is                   Lemma: be
# the                  Lemma: the
# discipline           Lemma: discipline
# within               Lemma: within
# pharmaceutical       Lemma: pharmaceutical
# science              Lemma: science
# that                 Lemma: that
# addresses            Lemma: address
# the                  Lemma: the
# identification       Lemma: identification
# ,                    Lemma: ,
#
#                     Lemma:
#
# evaluation           Lemma: evaluation
# ,                    Lemma: ,
# and                  Lemma: and
# mitigation           Lemma: mitigation
# of                   Lemma: of
# adverse              Lemma: adverse
# effects              Lemma: effect
# and                  Lemma: and
# other                Lemma: other
# drug                 Lemma: drug
# -                    Lemma: -
# related              Lemma: relate
# problems             Lemma: problem
# associated           Lemma: associate
# with                 Lemma: with
# pharmaceutical       Lemma: pharmaceutical
# products             Lemma: product
# .                    Lemma: .
# A                    Lemma: a
# central              Lemma: central
# concern              Lemma: concern
# is                   Lemma: be
#
#                     Lemma:
#
# adverse              Lemma: adverse
# drug                 Lemma: drug
# reactions            Lemma: reaction
# ,                    Lemma: ,
# defined              Lemma: define
# as                   Lemma: as
# harmful              Lemma: harmful
# and                  Lemma: and
# unintended           Lemma: unintended
# responses            Lemma: response
# to                   Lemma: to
# a                    Lemma: a
# medicinal            Lemma: medicinal
# product              Lemma: product
# .                    Lemma: .
#
# --- Medication Errors ---
# Incident             Lemma: incident
# reports              Lemma: report
# of                   Lemma: of
# medication           Lemma: medication
# errors               Lemma: error
# are                  Lemma: be
# valuable             Lemma: valuable
# learning             Lemma: learn
# resources            Lemma: resource
# for                  Lemma: for
# improving            Lemma: improve
# patient              Lemma: patient
# safety               Lemma: safety
# .                    Lemma: .
# Pertinent            Lemma: pertinent
# information          Lemma: information
# is                   Lemma: be
# often                Lemma: often
#
#                     Lemma:
#
# contained            Lemma: contain
# within               Lemma: within
# unstructured         Lemma: unstructured
# free                 Lemma: free
# text                 Lemma: text
# ,                    Lemma: ,
# which                Lemma: which
# prevents             Lemma: prevent
# automated            Lemma: automate
# analysis             Lemma: analysis
# and                  Lemma: and
# limits               Lemma: limit
# the                  Lemma: the
# usefulness           Lemma: usefulness
# of                   Lemma: of
# these                Lemma: these
# data                 Lemma: datum
# .                    Lemma: .
# NLP                  Lemma: NLP
# can                  Lemma: can
# structure            Lemma: structure
# this                 Lemma: this
# free                 Lemma: free
#
#                     Lemma:
#
# text                 Lemma: text
# automatically        Lemma: automatically
# and                  Lemma: and
# retrieve             Lemma: retrieve
# relevant             Lemma: relevant
# past                 Lemma: past
# incidents            Lemma: incident
# and                  Lemma: and
# learning             Lemma: learn
# materials            Lemma: material
#
# --- Incident Reporting ---
# Key                  Lemma: key
# components           Lemma: component
# of                   Lemma: of
# an                   Lemma: an
# incident             Lemma: incident
# investigation        Lemma: investigation
# report               Lemma: report
# include              Lemma: include
# :                    Lemma: :
# Incident             Lemma: Incident
# Overview             Lemma: Overview
# —                    Lemma: —
# a                    Lemma: a
# brief                Lemma: brief
# summary              Lemma: summary
# including            Lemma: include
# date                 Lemma: date
# ,                    Lemma: ,
# time                 Lemma: time
# ,                    Lemma: ,
# location             Lemma: location
# ,                    Lemma: ,
# and                  Lemma: and
#
#                     Lemma:
#
# nature               Lemma: nature
# of                   Lemma: of
# the                  Lemma: the
# incident             Lemma: incident
# ;                    Lemma: ;
# Background           Lemma: Background
# Information          Lemma: Information
# —                    Lemma: —
# a                    Lemma: a
# description          Lemma: description
# of                   Lemma: of
# site                 Lemma: site
# conditions           Lemma: condition
# ,                    Lemma: ,
# equipment            Lemma: equipment
# ,                    Lemma: ,
# and                  Lemma: and
# personnel            Lemma: personnel
# involved             Lemma: involve
# ;                    Lemma: ;
# Summary              Lemma: Summary
# of                   Lemma: of
# Findings             Lemma: Findings
# —                    Lemma: —
# linking              Lemma: link
#
#                     Lemma:
#
# identified           Lemma: identify
# root                 Lemma: root
# causes               Lemma: cause
# and                  Lemma: and
# contributing         Lemma: contribute
# factors              Lemma: factor
# ;                    Lemma: ;
# and                  Lemma: and
# Recommendations      Lemma: recommendation
# —                    Lemma: —
# specific             Lemma: specific
# corrective           Lemma: corrective
# and                  Lemma: and
# preventive           Lemma: preventive
# actions              Lemma: action
# .                    Lemma: .

# %%
# 4. Sentence Segmentation
print("=== Sentences ===\n")

for category, doc in docs.items():
    print(f"\n--- {category} ---")
    
    for sent in doc.sents:
        print(sent.text)
# Out:
# === Sentences ===
#
#
# --- Industrial Safety ---
# The personnel directly involved were Alex and Maya.
# Initial inspection indicates a potential hydraulic fluid leakage.
#
# Documentation of Incident:
# An incident report was prepared with details of the event, initial observations, and photographs of the
# affected area.
# Root Cause Analysis: Preliminary findings suggest that inadequate maintenance led to the hydraulic system’s malfunction
#
# --- Mining Safety ---
# To achieve the goal of preventing serious injuries and fatalities, it is important for a mine site to analyze site specific
# mine safety data.
# The advances in natural language processing create an opportunity to develop machine learning tools to automate analysis
# of mine health and safety management systems data without requiring experts at every mine site.
# If causation and associated details can be
# automatically extracted from the safety reports, NLP can be used to quickly gain insight into safety incidents from historical reports that
# are filed away in the safety management databases.
#
# --- Pharmacovigilance ---
# Pharmacovigilance, also known as drug safety, is the discipline within pharmaceutical science that addresses the identification,
# evaluation, and mitigation of adverse effects and other drug-related problems associated with pharmaceutical products.
# A central concern is
# adverse drug reactions, defined as harmful and unintended responses to a medicinal product.
#
# --- Medication Errors ---
# Incident reports of medication errors are valuable learning resources for improving patient safety.
# Pertinent information is often
# contained within unstructured free text, which prevents automated analysis and limits the usefulness of these data.
# NLP can structure this free
# text automatically and retrieve relevant past incidents and learning materials
#
# --- Incident Reporting ---
# Key components of an incident investigation report include: Incident Overview — a brief summary including date, time, location, and
# nature of the incident; Background Information — a description of site conditions, equipment, and personnel involved; Summary of Findings — linking
# identified root causes and contributing factors; and Recommendations — specific corrective and preventive actions.

# %%
# 5. Stop Word Removal
print("\n=== Stop Word Removal ===\n")

for category, doc in docs.items():
    print(f"\n--- {category} ---")
    
    filtered_tokens = [
        token.text for token in doc
        if not token.is_stop and not token.is_punct
    ]
    
    print("Filtered Tokens:", filtered_tokens)
# Out:
# === Stop Word Removal ===
#
#
# --- Industrial Safety ---
# Filtered Tokens: ['personnel', 'directly', 'involved', 'Alex', 'Maya', 'Initial', 'inspection', 'indicates', 'potential', 'hydraulic', 'fluid', 'leakage', '\n', 'Documentation', 'Incident', 'incident', 'report', 'prepared', 'details', 'event', 'initial', 'observations', 'photographs', '\n', 'affected', 'area', 'Root', 'Cause', 'Analysis', 'Preliminary', 'findings', 'suggest', 'inadequate', 'maintenance', 'led', 'hydraulic', 'system', 'malfunction']
#
# --- Mining Safety ---
# Filtered Tokens: ['achieve', 'goal', 'preventing', 'injuries', 'fatalities', 'important', 'site', 'analyze', 'site', 'specific', '\n', 'safety', 'data', 'advances', 'natural', 'language', 'processing', 'create', 'opportunity', 'develop', 'machine', 'learning', 'tools', 'automate', 'analysis', '\n', 'health', 'safety', 'management', 'systems', 'data', 'requiring', 'experts', 'site', 'causation', 'associated', 'details', '\n', 'automatically', 'extracted', 'safety', 'reports', 'NLP', 'quickly', 'gain', 'insight', 'safety', 'incidents', 'historical', 'reports', '\n', 'filed', 'away', 'safety', 'management', 'databases']
#
# --- Pharmacovigilance ---
# Filtered Tokens: ['Pharmacovigilance', 'known', 'drug', 'safety', 'discipline', 'pharmaceutical', 'science', 'addresses', 'identification', '\n', 'evaluation', 'mitigation', 'adverse', 'effects', 'drug', 'related', 'problems', 'associated', 'pharmaceutical', 'products', 'central', 'concern', '\n', 'adverse', 'drug', 'reactions', 'defined', 'harmful', 'unintended', 'responses', 'medicinal', 'product']
#
# --- Medication Errors ---
# Filtered Tokens: ['Incident', 'reports', 'medication', 'errors', 'valuable', 'learning', 'resources', 'improving', 'patient', 'safety', 'Pertinent', 'information', '\n', 'contained', 'unstructured', 'free', 'text', 'prevents', 'automated', 'analysis', 'limits', 'usefulness', 'data', 'NLP', 'structure', 'free', '\n', 'text', 'automatically', 'retrieve', 'relevant', 'past', 'incidents', 'learning', 'materials']
#
# --- Incident Reporting ---
# Filtered Tokens: ['Key', 'components', 'incident', 'investigation', 'report', 'include', 'Incident', 'Overview', 'brief', 'summary', 'including', 'date', 'time', 'location', '\n', 'nature', 'incident', 'Background', 'Information', 'description', 'site', 'conditions', 'equipment', 'personnel', 'involved', 'Summary', 'Findings', 'linking', '\n', 'identified', 'root', 'causes', 'contributing', 'factors', 'Recommendations', 'specific', 'corrective', 'preventive', 'actions']

# %%
# 6. Parts of Speech Tagging with Explanation
print("\n=== Parts of Speech (POS) Tagging ===\n")

for category, doc in docs.items():
    print(f"\n--- {category} ---")
    print(f"{'Token':20} {'POS':10} Explanation")
    print("-" * 60)
    
    for token in doc:
        print(f"{token.text:20} {token.pos_:10} {spacy.explain(token.pos_)}")
# Out:
# === Parts of Speech (POS) Tagging ===
#
#
# --- Industrial Safety ---
# Token                POS        Explanation
# ------------------------------------------------------------
# The                  DET        determiner
# personnel            NOUN       noun
# directly             ADV        adverb
# involved             ADJ        adjective
# were                 AUX        auxiliary
# Alex                 PROPN      proper noun
# and                  CCONJ      coordinating conjunction
# Maya                 PROPN      proper noun
# .                    PUNCT      punctuation
# Initial              ADJ        adjective
# inspection           NOUN       noun
# indicates            VERB       verb
# a                    DET        determiner
# potential            ADJ        adjective
# hydraulic            ADJ        adjective
# fluid                NOUN       noun
# leakage              NOUN       noun
# .                    PUNCT      punctuation
#
#                     SPACE      space
# Documentation        PROPN      proper noun
# of                   ADP        adposition
# Incident             PROPN      proper noun
# :                    PUNCT      punctuation
# An                   DET        determiner
# incident             NOUN       noun
# report               NOUN       noun
# was                  AUX        auxiliary
# prepared             VERB       verb
# with                 ADP        adposition
# details              NOUN       noun
# of                   ADP        adposition
# the                  DET        determiner
# event                NOUN       noun
# ,                    PUNCT      punctuation
# initial              ADJ        adjective
# observations         NOUN       noun
# ,                    PUNCT      punctuation
# and                  CCONJ      coordinating conjunction
# photographs          NOUN       noun
# of                   ADP        adposition
# the                  DET        determiner
#
#                     SPACE      space
# affected             ADJ        adjective
# area                 NOUN       noun
# .                    PUNCT      punctuation
# Root                 PROPN      proper noun
# Cause                PROPN      proper noun
# Analysis             NOUN       noun
# :                    PUNCT      punctuation
# Preliminary          ADJ        adjective
# findings             NOUN       noun
# suggest              VERB       verb
# that                 SCONJ      subordinating conjunction
# inadequate           ADJ        adjective
# maintenance          NOUN       noun
# led                  VERB       verb
# to                   ADP        adposition
# the                  DET        determiner
# hydraulic            ADJ        adjective
# system               NOUN       noun
# ’s                   PART       particle
# malfunction          NOUN       noun
#
# --- Mining Safety ---
# Token                POS        Explanation
# ------------------------------------------------------------
# To                   PART       particle
# achieve              VERB       verb
# the                  DET        determiner
# goal                 NOUN       noun
# of                   ADP        adposition
# preventing           VERB       verb
# serious              ADJ        adjective
# injuries             NOUN       noun
# and                  CCONJ      coordinating conjunction
# fatalities           NOUN       noun
# ,                    PUNCT      punctuation
# it                   PRON       pronoun
# is                   AUX        auxiliary
# important            ADJ        adjective
# for                  SCONJ      subordinating conjunction
# a                    DET        determiner
# mine                 NOUN       noun
# site                 NOUN       noun
# to                   PART       particle
# analyze              VERB       verb
# site                 NOUN       noun
# specific             ADJ        adjective
#
#                     SPACE      space
# mine                 ADJ        adjective
# safety               NOUN       noun
# data                 NOUN       noun
# .                    PUNCT      punctuation
# The                  DET        determiner
# advances             NOUN       noun
# in                   ADP        adposition
# natural              ADJ        adjective
# language             NOUN       noun
# processing           NOUN       noun
# create               VERB       verb
# an                   DET        determiner
# opportunity          NOUN       noun
# to                   PART       particle
# develop              VERB       verb
# machine              NOUN       noun
# learning             NOUN       noun
# tools                NOUN       noun
# to                   PART       particle
# automate             VERB       verb
# analysis             NOUN       noun
#
#                     SPACE      space
# of                   ADP        adposition
# mine                 ADJ        adjective
# health               NOUN       noun
# and                  CCONJ      coordinating conjunction
# safety               NOUN       noun
# management           NOUN       noun
# systems              NOUN       noun
# data                 NOUN       noun
# without              ADP        adposition
# requiring            VERB       verb
# experts              NOUN       noun
# at                   ADP        adposition
# every                DET        determiner
# mine                 NOUN       noun
# site                 NOUN       noun
# .                    PUNCT      punctuation
# If                   SCONJ      subordinating conjunction
# causation            NOUN       noun
# and                  CCONJ      coordinating conjunction
# associated           VERB       verb
# details              NOUN       noun
# can                  AUX        auxiliary
# be                   AUX        auxiliary
#
#                     SPACE      space
# automatically        ADV        adverb
# extracted            VERB       verb
# from                 ADP        adposition
# the                  DET        determiner
# safety               NOUN       noun
# reports              NOUN       noun
# ,                    PUNCT      punctuation
# NLP                  PROPN      proper noun
# can                  AUX        auxiliary
# be                   AUX        auxiliary
# used                 VERB       verb
# to                   PART       particle
# quickly              ADV        adverb
# gain                 VERB       verb
# insight              NOUN       noun
# into                 ADP        adposition
# safety               NOUN       noun
# incidents            NOUN       noun
# from                 ADP        adposition
# historical           ADJ        adjective
# reports              NOUN       noun
# that                 PRON       pronoun
#
#                     SPACE      space
# are                  AUX        auxiliary
# filed                VERB       verb
# away                 ADV        adverb
# in                   ADP        adposition
# the                  DET        determiner
# safety               NOUN       noun
# management           NOUN       noun
# databases            NOUN       noun
# .                    PUNCT      punctuation
#
# --- Pharmacovigilance ---
# Token                POS        Explanation
# ------------------------------------------------------------
# Pharmacovigilance    NOUN       noun
# ,                    PUNCT      punctuation
# also                 ADV        adverb
# known                VERB       verb
# as                   ADP        adposition
# drug                 NOUN       noun
# safety               NOUN       noun
# ,                    PUNCT      punctuation
# is                   AUX        auxiliary
# the                  DET        determiner
# discipline           NOUN       noun
# within               ADP        adposition
# pharmaceutical       ADJ        adjective
# science              NOUN       noun
# that                 PRON       pronoun
# addresses            VERB       verb
# the                  DET        determiner
# identification       NOUN       noun
# ,                    PUNCT      punctuation
#
#                     SPACE      space
# evaluation           NOUN       noun
# ,                    PUNCT      punctuation
# and                  CCONJ      coordinating conjunction
# mitigation           NOUN       noun
# of                   ADP        adposition
# adverse              ADJ        adjective
# effects              NOUN       noun
# and                  CCONJ      coordinating conjunction
# other                ADJ        adjective
# drug                 NOUN       noun
# -                    PUNCT      punctuation
# related              VERB       verb
# problems             NOUN       noun
# associated           VERB       verb
# with                 ADP        adposition
# pharmaceutical       ADJ        adjective
# products             NOUN       noun
# .                    PUNCT      punctuation
# A                    DET        determiner
# central              ADJ        adjective
# concern              NOUN       noun
# is                   AUX        auxiliary
#
#                     SPACE      space
# adverse              ADJ        adjective
# drug                 NOUN       noun
# reactions            NOUN       noun
# ,                    PUNCT      punctuation
# defined              VERB       verb
# as                   ADP        adposition
# harmful              ADJ        adjective
# and                  CCONJ      coordinating conjunction
# unintended           ADJ        adjective
# responses            NOUN       noun
# to                   ADP        adposition
# a                    DET        determiner
# medicinal            ADJ        adjective
# product              NOUN       noun
# .                    PUNCT      punctuation
#
# --- Medication Errors ---
# Token                POS        Explanation
# ------------------------------------------------------------
# Incident             NOUN       noun
# reports              NOUN       noun
# of                   ADP        adposition
# medication           NOUN       noun
# errors               NOUN       noun
# are                  AUX        auxiliary
# valuable             ADJ        adjective
# learning             VERB       verb
# resources            NOUN       noun
# for                  ADP        adposition
# improving            VERB       verb
# patient              ADJ        adjective
# safety               NOUN       noun
# .                    PUNCT      punctuation
# Pertinent            ADJ        adjective
# information          NOUN       noun
# is                   AUX        auxiliary
# often                ADV        adverb
#
#                     SPACE      space
# contained            VERB       verb
# within               ADP        adposition
# unstructured         ADJ        adjective
# free                 ADJ        adjective
# text                 NOUN       noun
# ,                    PUNCT      punctuation
# which                PRON       pronoun
# prevents             VERB       verb
# automated            VERB       verb
# analysis             NOUN       noun
# and                  CCONJ      coordinating conjunction
# limits               VERB       verb
# the                  DET        determiner
# usefulness           NOUN       noun
# of                   ADP        adposition
# these                DET        determiner
# data                 NOUN       noun
# .                    PUNCT      punctuation
# NLP                  PROPN      proper noun
# can                  AUX        auxiliary
# structure            VERB       verb
# this                 DET        determiner
# free                 ADJ        adjective
#
#                     SPACE      space
# text                 NOUN       noun
# automatically        ADV        adverb
# and                  CCONJ      coordinating conjunction
# retrieve             VERB       verb
# relevant             ADJ        adjective
# past                 ADJ        adjective
# incidents            NOUN       noun
# and                  CCONJ      coordinating conjunction
# learning             VERB       verb
# materials            NOUN       noun
#
# --- Incident Reporting ---
# Token                POS        Explanation
# ------------------------------------------------------------
# Key                  ADJ        adjective
# components           NOUN       noun
# of                   ADP        adposition
# an                   DET        determiner
# incident             NOUN       noun
# investigation        NOUN       noun
# report               NOUN       noun
# include              VERB       verb
# :                    PUNCT      punctuation
# Incident             PROPN      proper noun
# Overview             PROPN      proper noun
# —                    PUNCT      punctuation
# a                    DET        determiner
# brief                ADJ        adjective
# summary              NOUN       noun
# including            VERB       verb
# date                 NOUN       noun
# ,                    PUNCT      punctuation
# time                 NOUN       noun
# ,                    PUNCT      punctuation
# location             NOUN       noun
# ,                    PUNCT      punctuation
# and                  CCONJ      coordinating conjunction
#
#                     SPACE      space
# nature               NOUN       noun
# of                   ADP        adposition
# the                  DET        determiner
# incident             NOUN       noun
# ;                    PUNCT      punctuation
# Background           PROPN      proper noun
# Information          PROPN      proper noun
# —                    PUNCT      punctuation
# a                    DET        determiner
# description          NOUN       noun
# of                   ADP        adposition
# site                 NOUN       noun
# conditions           NOUN       noun
# ,                    PUNCT      punctuation
# equipment            NOUN       noun
# ,                    PUNCT      punctuation
# and                  CCONJ      coordinating conjunction
# personnel            NOUN       noun
# involved             VERB       verb
# ;                    PUNCT      punctuation
# Summary              PROPN      proper noun
# of                   ADP        adposition
# Findings             PROPN      proper noun
# —                    PUNCT      punctuation
# linking              VERB       verb
#
#                     SPACE      space
# identified           VERB       verb
# root                 NOUN       noun
# causes               NOUN       noun
# and                  CCONJ      coordinating conjunction
# contributing         VERB       verb
# factors              NOUN       noun
# ;                    PUNCT      punctuation
# and                  CCONJ      coordinating conjunction
# Recommendations      NOUN       noun
# —                    PUNCT      punctuation
# specific             ADJ        adjective
# corrective           ADJ        adjective
# and                  CCONJ      coordinating conjunction
# preventive           ADJ        adjective
# actions              NOUN       noun
# .                    PUNCT      punctuation
