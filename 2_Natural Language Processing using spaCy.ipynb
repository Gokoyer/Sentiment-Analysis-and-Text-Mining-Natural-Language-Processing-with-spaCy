# %%
# Install spaCy and download the English model if not already installed
# !pip install spacy
# !python -m spacy download en_core_web_sm

import spacy

# Load the spaCy English model
nlp = spacy.load("en_core_web_sm")

# Example text
text = "The personnel directly involved were Alex and Maya. Initial inspection indicates a potential hydraulic fluid leakage. Documentation of Incident: An incident report was prepared with details of the event, initial observations, and photographs of the affected area. Root Cause Analysis: Preliminary findings suggest that inadequate maintenance led to the hydraulic system’s malfunction."

# Process the text
doc = nlp(text)

print("\n")
